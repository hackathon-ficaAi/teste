# %% [markdown]
# <a href="https://colab.research.google.com/github/hackathon-ficaAi/teste/blob/data-science/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('/content/churn_dataset_5000.csv')

# Display the first 5 rows of the DataFrame
display(df.head(20))
# Out:
#    customer_id  idade genero data_inicio_assinatura tipo_plano  valor_mensal  \
# 0       C00001     56    NaN             2020-07-26       Plus          59.9
# 1       C00002     69      M             2024-11-24    Premium          29.9
# 2       C00003     46      F             2023-05-29    Premium          59.9
# 3       C00004     32      M             2023-07-09      Basic          29.9
# 4       C00005     60      F             2021-02-13      Basic          59.9
# 5       C00006     25    NaN             2020-11-26       Plus          39.9
# 6       C00007     38      M             2020-12-09      Basic          39.9
# 7       C00008     56      M             2022-09-15      Basic          59.9
# 8       C00009     36      M             2022-02-09    Premium          29.9
# 9       C00010     40      M             2020-03-14      Basic          29.9
# 10      C00011     28      F             2024-07-18      Basic          29.9
# ...
